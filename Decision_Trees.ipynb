# %% [markdown]
# <a href="https://colab.research.google.com/github/ShireenKachroo/Basic-ML-Algos/blob/main/Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df = df[["Survived","Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]]

df["Age"] = df["Age"].fillna(df["Age"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop("Survived", axis=1)  # input features
y = df["Survived"]               # target

# %% [markdown]
# SPLIT TRAINING AND TESTING DATASET

# %%
X_train, X_test, y_train, y_test =  train_test_split(X,y,test_size = 0.3, random_state = 42)

# %% [markdown]
# INITIALIZE MODEL

# %%
decisionTree = DecisionTreeClassifier(random_state = 42)

# %% [markdown]
# TRAIN MODEL

# %%
decisionTree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# PREDICT

# %%
y_predict = decisionTree.predict(X_test)

# %% [markdown]
# MODEL EVALUATION

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.746268656716418

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78       157
#            1       0.70      0.68      0.69       111
#
#     accuracy                           0.75       268
#    macro avg       0.74      0.74      0.74       268
# weighted avg       0.75      0.75      0.75       268

# %% [markdown]
# CHECK OVERFITTING

# %%
train_acc = decisionTree.score(X_train,y_train)
test_acc = decisionTree.score(X_test,y_test)

train_acc,test_acc
# Out:
# (0.9807383627608347, 0.746268656716418)

# %% [markdown]
# REGULARIZATION

# %%
dt = DecisionTreeClassifier(
    criterion="entropy",
    max_depth=4,
    max_features="sqrt",
    min_samples_leaf=10,
    random_state=42
)

dt.fit(X_train, y_train)

dt.score(X_train, y_train), dt.score(X_test, y_test)
# Out:
# (0.8089887640449438, 0.7873134328358209)
